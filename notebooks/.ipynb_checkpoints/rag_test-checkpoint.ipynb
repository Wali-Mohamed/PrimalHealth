# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
from bs4 import BeautifulSoup
import glob
import pandas as pd
import numpy as np
import re

# %%
# Load HTML files
def wrangle(paths):
    dfs=[]
    # forward fill after removed text from date column
    def clean_date(date):
                # Regular expression pattern for valid dates (e.g., '13 March 2019')
                pattern = r'^\d{1,2}\s\w+\s\d{4}$'  # Matches 'DD Month YYYY'
                if re.match(pattern, date):
                    return date
                else:
                    return None  # Replace invalid dates with None
    
    for html in paths:
        
        with open( html, 'r', encoding='utf-8') as file:
            soup = BeautifulSoup(file, 'html.parser')
    
            # Extract messages
            messages = []
            for message in soup.find_all('div', class_='message'):
                date = message.find('div', class_='body details').text.strip() if message.find('div', class_='body details') else None
                time = message.find('div', class_='date').text.strip() if message.find('div', class_='date') else None
                user = message.find('div', class_='from_name').text.strip() if message.find('div', class_='from_name') else None
                content = message.find('div', class_='text').text.strip() if message.find('div', class_='text') else None
                messages.append({"Date":date, "Time":time, "User": user,"Content": content})
            
            # Convert to DataFrame
            df = pd.DataFrame(messages)
            # fill in the na values by forward fill for dates
            df['Date']=df['Date'].ffill()
            # transform the date column by replacing any message about 'someone invited someone' in the group or removed someone with none
            df['Date']=df['Date'].apply(clean_date)
            df['Date']=df['Date'].ffill()
            # drop rows that have three nans. It is the date heading
            df=df.dropna(thresh=2)
            # forward fill user where nan
            df['User']=df['User'].ffill()
            # drop empty content it is usually pics
            df=df.dropna(subset='Content')
            dfs.append(df)
            print(len(dfs))
        return dfs

# %%
# file pattern
file_pattern=r'C:\Users\user\Documents\LLM Zoomcamp\Project\data\raw_data\messages*.html'

# %%
# Get a list of all matching files
files = glob.glob(file_pattern)  # we matched 438 files
len(files)
# Out:
# 438

# %%
# Save to CSV
dfs=wrangle(files)
# df=pd.concat(dfs, ignore_index=True)
dfs
# Out:
#                Date  Time  User Content
# 0  11 December 2018  None  None    None
# 1
# [                  Date   Time             User  \
#  6     14 February 2019  08:02          Silmavi
#  8     14 February 2019  08:05  Deleted Account
#  9     14 February 2019  08:05          Silmavi
#  11    14 February 2019  08:07  Deleted Account
#  13    14 February 2019  08:08          Silmavi
#  ...                ...    ...              ...
#  1007  24 February 2019  16:36  Deleted Account
#  1008  24 February 2019  16:39  Deleted Account
#  1009  24 February 2019  16:42  Deleted Account
#  1010  24 February 2019  16:45  Deleted Account
#  1011  24 February 2019  16:46  Deleted Account
#
#                                                  Content
#  6                                                Hello!
#  8                          sooo, detox finished when? 😄
#  9                       Here we can talk about Aajonus?
#  11                             Detox! Hell yeah Aajonus
#  13                                                 😂😂😂😂
#  ...                                                 ...
#  1007            Well I guess my body knows wgen to stop
#  1008                           That means more herring!
#  1009                      Is kefir a good source of K2?
#  1010  Isn't the process of fermenting also producing...
#  1011                                                Yes
#
#  [948 rows x 4 columns]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 948 entries, 0 to 947
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     948 non-null    object
#  1   Time     948 non-null    object
#  2   User     948 non-null    object
#  3   Content  948 non-null    object
# dtypes: object(4)
# memory usage: 29.8+ KB

# %%
path=r'C:\Users\user\Documents\LLM Zoomcamp\Project\data\raw_data\messages4.html'
def wrangle(path):
    with open( path, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, 'html.parser')
        
        # Extract messages
        messages = []
        for message in soup.find_all('div', class_='message'):
            date = message.find('div', class_='body details').text.strip() if message.find('div', class_='body details') else None
            time = message.find('div', class_='date').text.strip() if message.find('div', class_='date') else None
            user = message.find('div', class_='from_name').text.strip() if message.find('div', class_='from_name') else None
            content = message.find('div', class_='text').text.strip() if message.find('div', class_='text') else None
            messages.append({"Date":date, "Time":time, "User": user,"Content": content})
        
        # Convert to DataFrame
        df = pd.DataFrame(messages)
        print(df.isnull().sum())
        # fill in the na values by forward fill for dates
        df['Date']=df['Date'].ffill()
        # replace any message about 'someone invited someone' in the group or removed someone with none
        def clean_date(date):
            # Regular expression pattern for valid dates (e.g., '13 March 2019')
            pattern = r'^\d{1,2}\s\w+\s\d{4}$'  # Matches 'DD Month YYYY'
            if re.match(pattern, date):
                return date
            else:
                return None  # Replace invalid dates with None
        df['Date']=df['Date'].apply(clean_date)
        df['Date']=df['Date'].ffill()
        df=df.dropna(thresh=2)
        df['User']=df['User'].ffill()
        df=df.dropna(subset='Content')
        return df

# %%
df=wrangle(path)
df.isnull().sum()
# Out:
# Date       984
# Time        31
# User       496
# Content     87
# dtype: int64
# Date       0
# Time       0
# User       0
# Content    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 928 entries, 1 to 1014
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     928 non-null    object
#  1   Time     928 non-null    object
#  2   User     928 non-null    object
#  3   Content  928 non-null    object
# dtypes: object(4)
# memory usage: 36.2+ KB

# %%
df=df.dropna(thresh=2)

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     1015 non-null   object
#  1   Time     1015 non-null   object
#  2   User     519 non-null    object
#  3   Content  1015 non-null   object
# dtypes: object(4)
# memory usage: 31.8+ KB
# Date         0
# Time         0
# User       496
# Content      0
# dtype: int64

# %%
df.head()
# Out:
#             Date   Time             User  \
# 1  13 March 2019  14:44  Deleted Account
# 2  13 March 2019  14:44          Silmavi
# 3  13 March 2019  14:46             None
# 4  13 March 2019  14:49  Deleted Account
# 5  13 March 2019  14:49          Silmavi
#
#                                      Content
# 1  especially with the stored vegetable oils
# 2                           Do you put milk?
# 3  Acv must be eco or can it be supernarket?
# 4               how much milk, salt and acv?
# 5                                         😍😍

# %%
df[df['time_is_none']==True]
# Out:
# Empty DataFrame
# Columns: [Date, Time, User, Content, date_is_none, time_is_none]
# Index: []

# %%
def clean_date(date):
    # Regular expression pattern for valid dates (e.g., '13 March 2019')
    pattern = r'^\d{1,2}\s\w+\s\d{4}$'  # Matches 'DD Month YYYY'
    if re.match(pattern, date):
        return date
    else:
        return None  # Replace invalid dates with None
date='24, jan,  1999'
clean_date(date)

# %%
# Fill NaN values with the previous value
df_filled = df.ffill()

df_filled.head(50)
# Out:
#              Date             User  \
# 0   13 March 2019             None
# 1   13 March 2019  Deleted Account
# 2   13 March 2019          Silmavi
# 3   13 March 2019          Silmavi
# 4   13 March 2019  Deleted Account
# 5   13 March 2019          Silmavi
# 6   13 March 2019          Silmavi
# 7   13 March 2019          Silmavi
# 8   13 March 2019          Silmavi
# 9   13 March 2019  Deleted Account
# 10  13 March 2019          Silmavi
# 11  13 March 2019          Silmavi
# 12  13 March 2019          Silmavi
# 13  13 March 2019          Silmavi
# 14  13 March 2019          Silmavi
# 15  13 March 2019          Silmavi
# 16  13 March 2019          Silmavi
# 17  13 March 2019          Silmavi
# 18  13 March 2019          Silmavi
# 19  13 March 2019          Silmavi
# 20  13 March 2019          Silmavi
# 21  13 March 2019          Silmavi
# 22  13 March 2019          Silmavi
# 23  13 March 2019          Silmavi
# 24  13 March 2019          Silmavi
# 25  13 March 2019          Silmavi
# 26  13 March 2019          Silmavi
# 27  13 March 2019          Silmavi
# 28  13 March 2019          Silmavi
# 29  13 March 2019  Deleted Account
# 30  13 March 2019  Deleted Account
# 31  13 March 2019  Deleted Account
# 32  13 March 2019  Deleted Account
# 33  13 March 2019  Deleted Account
# 34  13 March 2019          Silmavi
# 35  13 March 2019  Deleted Account
# 36  13 March 2019  Deleted Account
# 37  13 March 2019          Silmavi
# 38  13 March 2019          Silmavi
# 39  13 March 2019  Deleted Account
# 40  13 March 2019  Deleted Account
# 41  13 March 2019          Silmavi
# 42  13 March 2019  Deleted Account
# 43  13 March 2019             Allu
# 44  13 March 2019  Deleted Account
# 45  13 March 2019          Silmavi
# 46  13 March 2019          Silmavi
# 47  13 March 2019          Silmavi
# 48  13 March 2019  Deleted Account
# 49  13 March 2019  Deleted Account
#
#                                               Content
# 0
# 1           especially with the stored vegetable oils
# 2                                    Do you put milk?
# 3           Acv must be eco or can it be supernarket?
# 4                        how much milk, salt and acv?
# 5                                                  😍😍
# 6                                  I tell my husband!
# 7                                                 😂😂😂
# 8                                       Regular salt?
# 9                                    ok lets do this!
# 10              I used to take salt baths for osmosis
# 11                                                 Ok
# 12                                       Thanks Ring!
# 13                                            Really?
# 14                  Noooooo.i have holstain poor milk
# 15                                     How much milk?
# 16
# 17                                         Like this?
# 18                                                 Ok
# 19    You really enjoy the bath with ice cubes close?
# 20                                                 Ok
# 21      With 37 c i could stand 20mts in salted water
# 22                   I may use the cubes to stand 90m
# 23      You rinse yourself with water after the bath?
# 24  Me too.Is the water and milk full of toxins af...
# 25  So it is just for one person.Better not that a...
# 26                                 👍👍 too small place
# 27                          Didn't thought about that
# 28                         45 is enough to melt oils?
# 29  I do baths everyday there is "wax" coming out ...
# 30  2tablespoons of salt.Milk 2 cups is enough.Use...
# 31  YES I used to wake up sweating and feeling bad...
# 32                                     after the bath
# 33  Perhaps. Aajonus said you could use coconut cr...
# 34                                              Ohhhh
# 35  First 45min only gets rid of body waste under ...
# 36  Yes I used to wake up with strong odor and I n...
# 37         Thanks sooo much for dtails.I must get fat
# 38  But how much?....i have slways weighed 35 when...
# 39                          about 10pounds overweight
# 40  and enough to feel comfortable in bath. the fa...
# 41  That happens to us.There us a tiger sleeping i...
# 42  if you lose fat then put on raw fat it will be...
# 43
# 44  Did you make it taste your food? It can perhap...
# 45             Tiger is invisible.... I just smell it
# 46                                 Maybe it is me....
# 47                           I don't understand sorry
# 48  Cooked fat is bigger than raw fat, cooking mak...
# 49             Aajonus was 30% bodyfat but looked 16%

# %%
df_filled.iloc[950:1009]
df_filled.isna().sum()
# Out:
# Date       478
# User         1
# Time         0
# Content      0
# dtype: int64

# %%
df_filled['Date'] = df_filled['Date'].apply(clean_date)

# Display the cleaned DataFrame
df_filled.head()
df_filled.iloc[200:220]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 df_filled['Date'] = df_filled['Date'].apply(clean_date)
#       3 # Display the cleaned DataFrame
#       4 df_filled.head()
#
# File ~\.virtualenvs\Project-v4EWajkE\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\.virtualenvs\Project-v4EWajkE\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\.virtualenvs\Project-v4EWajkE\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\.virtualenvs\Project-v4EWajkE\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\.virtualenvs\Project-v4EWajkE\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[130], line 4, in clean_date(date)
#       1 def clean_date(date):
#       2     # Regular expression pattern for valid dates (e.g., '13 March 2019')
#       3     pattern = r'^\d{1,2}\s\w+\s\d{4}$'  # Matches 'DD Month YYYY'
# ----> 4     if re.match(pattern, date):
#       5         return date
#       6     else:
#
# File ~\miniconda3\Lib\re\__init__.py:167, in match(pattern, string, flags)
#     164 def match(pattern, string, flags=0):
#     165     """Try to apply the pattern at the start of the string, returning
#     166     a Match object, or None if no match was found."""
# --> 167     return _compile(pattern, flags).match(string)
#
# TypeError: expected string or bytes-like object, got 'NoneType'

# %%
# Alternatively, you can use find method
title = soup.find('title').string if soup.find('title') else "No title found"

print(f"Title of the HTML page: {title}")
for i in soup.find_all('div', class_='message default clearfix'):
    div_with_title = message.find('div', class_='details').text.strip() if message.find('div', class_='date') else "Unknown"
    title_content = div_with_title.get('title', 'No title found') if div_with_title else 'No title found'
# Out:
# Title of the HTML page: Exported Data
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 7
#       5 for i in soup.find_all('div', class_='message default clearfix'):
#       6     div_with_title = message.find('div', class_='details').text.strip() if message.find('div', class_='date') else "Unknown"
# ----> 7     title_content = div_with_title.get('title', 'No title found') if div_with_title else 'No title found'
#
# AttributeError: 'str' object has no attribute 'get'

# %%
for i in soup.find_all('div', class_='message'):
     date = message.find('div', class_='date').text.strip() if message.find('div', class_='date') else "Unknown"
     timestamp=date['title'] if date and 'title' in date else "No title found"
     print(timestamp)
# Out:
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found
# No title found

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Exported Data
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="css/style.css" rel="stylesheet"/>
#   <script src="js/script.js" type="text/javascript">
#   </script>
#  </head>
#  <body onload="CheckLocation();">
#   <div class="page_wrap">
#    <div class="page_header">
#     <div class="content">
#      <div class="text bold">
#       Primal Diet
#      </div>
#     </div>
#    </div>
#    <div class="page_body chat_page">
#     <div class="history">
#      <a class="pagination block_link" href="messages3.html">
#       Previous messages
#      </a>
#      <div class="message service" id="message-32">
#       <div class="body details">
#        13 March 2019
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6311">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:44:06 UTC+00:00">
#         14:44
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         especially with the stored vegetable oils
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6312">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:44:37 UTC+00:00">
#         14:44
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6310" onclick="return GoToMessage(6310)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Do you put milk?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6316">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:46:24 UTC+00:00">
#         14:46
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6315" onclick="return GoToMessage(6315)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Acv must be eco or can it be supernarket?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6323">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:49:36 UTC+00:00">
#         14:49
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         how much milk, salt and acv?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6324">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:49:41 UTC+00:00">
#         14:49
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6321" onclick="return GoToMessage(6321)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         😍😍
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6325">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:49:55 UTC+00:00">
#         14:49
#        </div>
#        <div class="text">
#         I tell my husband!
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6327">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:49:59 UTC+00:00">
#         14:49
#        </div>
#        <div class="text">
#         😂😂😂
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6329">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:50:31 UTC+00:00">
#         14:50
#        </div>
#        <div class="text">
#         Regular salt?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6331">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:51:03 UTC+00:00">
#         14:51
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         ok lets do this!
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6334">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:51:16 UTC+00:00">
#         14:51
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         I used to take salt baths for osmosis
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6335">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:51:29 UTC+00:00">
#         14:51
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6333" onclick="return GoToMessage(6333)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Ok
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6337">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:52:24 UTC+00:00">
#         14:52
#        </div>
#        <div class="text">
#         Thanks Ring!
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6341">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:52:54 UTC+00:00">
#         14:52
#        </div>
#        <div class="text">
#         Really?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6343">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:53:13 UTC+00:00">
#         14:53
#        </div>
#        <div class="text">
#         Noooooo.i have holstain poor milk
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6347">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:53:57 UTC+00:00">
#         14:53
#        </div>
#        <div class="text">
#         How much milk?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6350">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:55:07 UTC+00:00">
#         14:55
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            960×1280, 85.1 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6351">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:55:15 UTC+00:00">
#         14:55
#        </div>
#        <div class="text">
#         Like this?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6352">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:55:25 UTC+00:00">
#         14:55
#        </div>
#        <div class="text">
#         Ok
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6355">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:56:23 UTC+00:00">
#         14:56
#        </div>
#        <div class="text">
#         You really enjoy the bath with ice cubes close?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6357">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:56:55 UTC+00:00">
#         14:56
#        </div>
#        <div class="text">
#         Ok
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6360">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:57:29 UTC+00:00">
#         14:57
#        </div>
#        <div class="text">
#         With 37 c i could stand 20mts in salted water
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6361">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:58:24 UTC+00:00">
#         14:58
#        </div>
#        <div class="text">
#         I may use the cubes to stand 90m
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6362">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 14:59:09 UTC+00:00">
#         14:59
#        </div>
#        <div class="text">
#         You rinse yourself with water after the bath?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6366">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:01:02 UTC+00:00">
#         15:01
#        </div>
#        <div class="text">
#         Me too.Is the water and milk full of toxins after the bath?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6368">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:02:31 UTC+00:00">
#         15:02
#        </div>
#        <div class="text">
#         So it is just for one person.Better not that another nember of the family also uses it?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6370">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:03:10 UTC+00:00">
#         15:03
#        </div>
#        <div class="text">
#         👍👍 too small place
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6375">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:06:13 UTC+00:00">
#         15:06
#        </div>
#        <div class="text">
#         Didn't thought about that
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6376">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:06:32 UTC+00:00">
#         15:06
#        </div>
#        <div class="text">
#         45 is enough to melt oils?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6382">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:42:09 UTC+00:00">
#         15:42
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         I do baths everyday there is "wax" coming out of me. For a while I had palpitations and cramps in heart, hands, and tingling feeling with "pops" on skin.
#         <br/>
#         It made grey slightly yellow/black stains on the bathtub.
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6384">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:43:18 UTC+00:00">
#         15:43
#        </div>
#        <div class="text">
#         2tablespoons of salt.
#         <br/>
#         Milk 2 cups is enough.
#         <br/>
#         Use skim milk because the cream is useless and waste in the bath.
#         <br/>
#         It is the minerals that bind with toxins.
#         <br/>
#         The toxins from the water with chemicals inside and the toxins coming out of your body.
#         <br/>
#         Salt also binds with some of them and it won't enter your skin because it's too big a mineral
#         <br/>
#         They bind with them so you don't absorb them.
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6386">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:44:30 UTC+00:00">
#         15:44
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6383" onclick="return GoToMessage(6383)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         YES I used to wake up sweating and feeling bad. Now after a few months I am always much more clean even if not bathing 2 days sometimes.
#         <br/>
#         Also after a really hot bath 90min or more the zen feeling is incredible. It can also give so much energy at the same time
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6387">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:44:35 UTC+00:00">
#         15:44
#        </div>
#        <div class="text">
#         after the bath
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6389">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:45:37 UTC+00:00">
#         15:45
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6385" onclick="return GoToMessage(6385)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Perhaps. Aajonus said you could use coconut cream if you want but said the dairy cream was wasted. Not sure. I don't use it. Prefer to eat it, it probably feeds me more than being spread throughout water IMO
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6393">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:47:08 UTC+00:00">
#         15:47
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6380" onclick="return GoToMessage(6380)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Ohhhh
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6394">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:48:16 UTC+00:00">
#         15:48
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6375" onclick="return GoToMessage(6375)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         First 45min only gets rid of body waste under the skin.
#         <br/>
#         After that it only STARTS melting and gets to the congestion in the lymphatic system, nodes (main ones in your neck, armpits, crotch, etc.)
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6395">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:49:28 UTC+00:00">
#         15:49
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6390" onclick="return GoToMessage(6390)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Yes I used to wake up with strong odor and I never managed to get  rid of body odor in my bedroom except with good wind blowing through the window, now it has reduced a lot even after a night of sleep. So I have better air  to breathe too!
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6396">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:49:51 UTC+00:00">
#         15:49
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         Thanks sooo much for dtails.I must get fat
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6397">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:50:35 UTC+00:00">
#         15:50
#        </div>
#        <div class="text">
#         But how much?....i have slways weighed 35 when i was omnivorous
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6398">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:50:55 UTC+00:00">
#         15:50
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         about 10pounds overweight
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6399">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:51:26 UTC+00:00">
#         15:51
#        </div>
#        <div class="text">
#         and enough to feel comfortable in bath. the fat surrounding you will arrest toxins and there will be less uncomfortable symptoms
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6400">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:52:01 UTC+00:00">
#         15:52
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6395" onclick="return GoToMessage(6395)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         That happens to us.There us a tiger sleeping in my bedroom and i have to open the windows so that it leaves
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6401">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:52:30 UTC+00:00">
#         15:52
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         if you lose fat then put on raw fat it will be heavier but less volume, so you can be fat and look normal or even trim if you've been long enough on the diet to have many tissues regenerated
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6402">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic2" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          A
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:53:02 UTC+00:00">
#         15:53
#        </div>
#        <div class="from_name">
#         Allu
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            762×1280, 74.3 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6403">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:53:18 UTC+00:00">
#         15:53
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6400" onclick="return GoToMessage(6400)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Did you make it taste your food? It can perhaps be a very good judge of quality
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6404">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:54:14 UTC+00:00">
#         15:54
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         Tiger is invisible.... I just smell it
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6405">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:54:39 UTC+00:00">
#         15:54
#        </div>
#        <div class="text">
#         Maybe it is me....
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6406">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:55:07 UTC+00:00">
#         15:55
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6401" onclick="return GoToMessage(6401)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         I don't understand sorry
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6407">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:56:34 UTC+00:00">
#         15:56
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6404" onclick="return GoToMessage(6404)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Cooked fat is bigger than raw fat, cooking make it swell 20/100 times.
#         <br/>
#         So if you eat cooked fat for the same energy you look fatter, more volume.
#         <br/>
#         Raw fat is smaller molecule, concentrated, dense and more firm.
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6408">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 15:56:49 UTC+00:00">
#         15:56
#        </div>
#        <div class="text">
#         Aajonus was 30% bodyfat but looked 16%
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6409">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:00:32 UTC+00:00">
#         16:00
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         I eat raw ground beef mostly.Ommekette cheese and fermented milk
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6410">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:00:50 UTC+00:00">
#         16:00
#        </div>
#        <div class="text">
#         Also raw eggs
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6411">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:02:18 UTC+00:00">
#         16:02
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         Nice. I think the area of improvement if you want is getting fattier cuts of meat.
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6412">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:02:54 UTC+00:00">
#         16:02
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         I understand now i can get fatter but look the same ....but the scale has to show the weigh i get even if i look skiiny?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6413">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:03:38 UTC+00:00">
#         16:03
#        </div>
#        <div class="text">
#         I get ground beef becsuse it had both and i can't find butter
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6414">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:04:00 UTC+00:00">
#         16:04
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         Cooked fats are liked balloons, big but not heavy. It's swollen fat.
#         <br/>
#         Raw is denser
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6415">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:05:30 UTC+00:00">
#         16:05
#        </div>
#        <div class="text">
#         Raw fats on your body will look less fat than cooked fat, however, to really be fat like Aajonus 30% and look 16% it takes several years on diet because at first the tissues need to hydrate and so they space up a little to make way for delivery of nutrients and it doesn't look trim, but still less fat than cooked
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6416">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:06:29 UTC+00:00">
#         16:06
#        </div>
#        <div class="text">
#         I had lost all my weight with fasting and when I did weigh gain on Primal I could compare very easily, for same weight on previous diet I looked 1.5times fattier perhaps
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6417">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:06:36 UTC+00:00">
#         16:06
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         May be i should drink more lubrication formula
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6418">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:07:18 UTC+00:00">
#         16:07
#        </div>
#        <div class="text">
#         But no butter is the deal now..
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6419">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:08:09 UTC+00:00">
#         16:08
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6417" onclick="return GoToMessage(6417)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Oh yes definitely. 25min after a meat meal for best absorption. it is delicious and feed all your poorly deserved body parts.
#         <br/>
#         However it needs to be butter otherwise it will not digest fast enough.
#         <br/>
#         Still if you do it with cream you will still get a good recipe that is not useless
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6420">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:08:51 UTC+00:00">
#         16:08
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         I lost a lot in crdivegan diet 5kilos.And i have fasted for four days with urine and lost weigh too Now i hsve better eat and nurture my body
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6421">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:10:05 UTC+00:00">
#         16:10
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6419" onclick="return GoToMessage(6419)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         I will do that I guess raw fermented cream us better than pasteurized butter
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6422">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:10:14 UTC+00:00">
#         16:10
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         Yes and if you ever want to lose weight just eat one raw egg at least every 5h and it will all drop off very fast without side effects from fasting or caloric restriction
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6423">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:10:54 UTC+00:00">
#         16:10
#        </div>
#        <div class="text">
#         Yes better indeed. Pasteurized butter wouldn't work for moisturizing anyway
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6426">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:13:01 UTC+00:00">
#         16:13
#        </div>
#        <div class="text">
#         also it makes you gain lean mass
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6427">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:13:07 UTC+00:00">
#         16:13
#        </div>
#        <div class="text">
#         without exercise
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6432">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:16:49 UTC+00:00">
#         16:16
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6419" onclick="return GoToMessage(6419)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         If i wait more time is useless?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6433">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:17:07 UTC+00:00">
#         16:17
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6432" onclick="return GoToMessage(6432)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Not useless, it is just optimal about 25min after a meat meal
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6434">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:17:34 UTC+00:00">
#         16:17
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         Ok! I must set the alarm...😅😅
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6435">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:17:49 UTC+00:00">
#         16:17
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         probably some meat proteins will have digested by then and will speed up moisturizing formula assimiliation but i'm not sure
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6436">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:18:04 UTC+00:00">
#         16:18
#        </div>
#        <div class="text">
#         if you eat fermented dairy it's also better 30min after meat meal
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6437">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:18:13 UTC+00:00">
#         16:18
#        </div>
#        <div class="text">
#         well it gives you time to prepare it :)
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6438">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:19:51 UTC+00:00">
#         16:19
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         I give my kids rare meat and they like to drink fermented milk with it.Is that ok?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6439">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:27:37 UTC+00:00">
#         16:27
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         Yes it will correct a little overacidity from cooked meat. dairy is slightly alkalizing because of its mineral content
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6440">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:28:17 UTC+00:00">
#         16:28
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         Great... they prefer meat s bit cooked
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6441">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:33:07 UTC+00:00">
#         16:33
#        </div>
#        <div class="text">
#         I guess i can drink  with the raw meat what is left of cream when making butter?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6442">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:37:11 UTC+00:00">
#         16:37
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         I think so
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6443">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:38:03 UTC+00:00">
#         16:38
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         I just made my first fermented butter!.
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6444">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:38:06 UTC+00:00">
#         16:38
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         If it makes a good quantity though you can take it 30min after the meat meal with honey, by itself if there is enough or with other dairy
#         <br/>
#         it will digest better and also be more filling
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6445">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:38:35 UTC+00:00">
#         16:38
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         Thanks!
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6446">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:38:49 UTC+00:00">
#         16:38
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message6443" onclick="return GoToMessage(6443)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Great! also if you let butter get moldy, like blue cheese, it gets predigested by mold, and you absorb 96% of it, 25% more than normal butter
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6448">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:39:36 UTC+00:00">
#         16:39
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         The goat butter i had got moldy.Blue stains i ate some
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6449">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:40:00 UTC+00:00">
#         16:40
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         I'm still waiting for mine to turn blue. However it apparently tastes similar to blue cheese.
#         <br/>
#         I can tell you maggot goat cheese tastes like gorgonzola and a bit spicy on tongue
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6450">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:40:01 UTC+00:00">
#         16:40
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         Shall i wash the butter in water?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6452">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic1" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:40:31 UTC+00:00">
#         16:40
#        </div>
#        <div class="from_name">
#         Deleted Account
#        </div>
#        <div class="text">
#         why?  it will put public water toxic chemicals and wash away good nutrients
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message6453">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:40:47 UTC+00:00">
#         16:40
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            960×1280, 89.8 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6454">
#       <div class="body">
#        <div class="pull_right date details" title="13.03.2019 16:40:52 UTC+00:00">
#         16:40
#        </div>
#        <div class="text">
#         My baby butter
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message6455">
#       <div class="body">
# ...
#         In reply to
#         <a href="#go_to_message7877" onclick="return GoToMessage(7877)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Looks like visceral fat.
#         <br/>
#         Recently bought some of this.
#         <br/>
#         It it so neutral. No taste at all.
#         <br/>
#         I questioned myself wtf am I eating🤔
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message7883">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 17:51:35 UTC+00:00">
#         17:51
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message7882" onclick="return GoToMessage(7882)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         What kind of far should i get?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7884">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 17:52:25 UTC+00:00">
#         17:52
#        </div>
#        <div class="text">
#         Is Tallow visceral fat?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message7885">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic7" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          AL
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 17:52:34 UTC+00:00">
#         17:52
#        </div>
#        <div class="from_name">
#         Antón Leitón
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            960×1280, 85.0 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message service" id="message7886">
#       <div class="body details">
#        Изолированный Проводник removed Изолированный Проводник
#       </div>
#      </div>
#      <div class="message default clearfix" id="message7887">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic2" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          A
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 17:58:46 UTC+00:00">
#         17:58
#        </div>
#        <div class="from_name">
#         Allu
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message7883" onclick="return GoToMessage(7883)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Any form of fat, I like bonemarrow and organ fat most
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message7888">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 18:03:30 UTC+00:00">
#         18:03
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         I like bone marrow and tallow.That tallow is from clean of antibiotics grass fed
#         <a href="beef.is">
#          beef.is
#         </a>
#         it ok to eat it?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7889">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 18:03:42 UTC+00:00">
#         18:03
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            960×1280, 120.3 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message7891">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 18:19:08 UTC+00:00">
#         18:19
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         What is funny?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message7894">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic5" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          S
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:02:57 UTC+00:00">
#         20:02
#        </div>
#        <div class="from_name">
#         Silmavi
#        </div>
#        <div class="text">
#         I see
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7898">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:03:50 UTC+00:00">
#         20:03
#        </div>
#        <div class="text">
#         I questioned that today eating this
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7900">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:04:08 UTC+00:00">
#         20:04
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            960×1280, 100.2 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7901">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:04:35 UTC+00:00">
#         20:04
#        </div>
#        <div class="text">
#         What is the white thing ...it was i side the mackerel
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7902">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:04:52 UTC+00:00">
#         20:04
#        </div>
#        <div class="text">
#         Inside.what organ is it?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7909">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:06:37 UTC+00:00">
#         20:06
#        </div>
#        <div class="text">
#         What?
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7911">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:06:55 UTC+00:00">
#         20:06
#        </div>
#        <div class="text">
#         It tastes like butter
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7912">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:07:21 UTC+00:00">
#         20:07
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            960×1280, 65.3 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7913">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:07:28 UTC+00:00">
#         20:07
#        </div>
#        <div class="text">
#         Was inside
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7914">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:07:51 UTC+00:00">
#         20:07
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            960×1280, 58.4 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7916">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:13:23 UTC+00:00">
#         20:13
#        </div>
#        <div class="text">
#         Look
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7918">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:13:40 UTC+00:00">
#         20:13
#        </div>
#        <div class="media_wrap clearfix">
#         <div class="media clearfix pull_left media_photo">
#          <div class="fill pull_left">
#          </div>
#          <div class="body">
#           <div class="title bold">
#            Photo
#           </div>
#           <div class="description">
#            Not included, change data exporting settings to download.
#           </div>
#           <div class="status details">
#            960×1280, 77.7 KB
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7919">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:14:13 UTC+00:00">
#         20:14
#        </div>
#        <div class="text">
#         This was in other mackerel
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7922">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:14:42 UTC+00:00">
#         20:14
#        </div>
#        <div class="text">
#         I couldn't find that one!
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7923">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:14:49 UTC+00:00">
#         20:14
#        </div>
#        <div class="text">
#         😂😂
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7925">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:15:03 UTC+00:00">
#         20:15
#        </div>
#        <div class="text">
#         Testickes😂😂
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7926">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:15:13 UTC+00:00">
#         20:15
#        </div>
#        <div class="text">
#         😳😳
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7927">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:15:16 UTC+00:00">
#         20:15
#        </div>
#        <div class="text">
#         Yes
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7928">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:15:31 UTC+00:00">
#         20:15
#        </div>
#        <div class="text">
#         They are butter like😂😂
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7929">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:15:44 UTC+00:00">
#         20:15
#        </div>
#        <div class="text">
#         Fulfilling!!
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7930">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:16:02 UTC+00:00">
#         20:16
#        </div>
#        <div class="text">
#         Can't stop laughing
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7931">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:16:21 UTC+00:00">
#         20:16
#        </div>
#        <div class="text">
#         Glad i ate them with no prejudice
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7932">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:16:48 UTC+00:00">
#         20:16
#        </div>
#        <div class="text">
#         I taste ovaries tomorrow
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7933">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:17:14 UTC+00:00">
#         20:17
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message7921" onclick="return GoToMessage(7921)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         Thanks for the information
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix joined" id="message7935">
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:18:56 UTC+00:00">
#         20:18
#        </div>
#        <div class="text">
#         This day made a difference....
#        </div>
#       </div>
#      </div>
#      <div class="message default clearfix" id="message7936">
#       <div class="pull_left userpic_wrap">
#        <div class="userpic userpic7" style="width: 42px; height: 42px">
#         <div class="initials" style="line-height: 42px">
#          AL
#         </div>
#        </div>
#       </div>
#       <div class="body">
#        <div class="pull_right date details" title="28.03.2019 20:26:56 UTC+00:00">
#         20:26
#        </div>
#        <div class="from_name">
#         Antón Leitón
#        </div>
#        <div class="reply_to details">
#         In reply to
#         <a href="#go_to_message7892" onclick="return GoToMessage(7892)">
#          this message
#         </a>
#        </div>
#        <div class="text">
#         🤣🤣🤣
#        </div>
#       </div>
#      </div>
#      <a class="pagination block_link" href="messages5.html">
#       Next messages
#      </a>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
# Load HTML file

for order, file in enumerate(files):
    
    with open( file, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, 'html.parser')
    
    # Extract messages
    messages = []
    for message in soup.find_all('div', class_='message'):
        user = message.find('div', class_='from_name').text.strip() if message.find('div', class_='from_name') else "Unknown"
        time = message.find('div', class_='date').text.strip() if message.find('div', class_='date') else "Unknown"
        content = message.find('div', class_='text').text.strip() if message.find('div', class_='text') else ""
        messages.append({"User": user, "Time": time, "Content": content})
    
    # Convert to DataFrame
    df = pd.DataFrame(messages)
    i=order+1
    

    # Save to CSV
    df.to_csv('../data/clean_data/telegram_conversation'+str(i)+'.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Load HTML file
# ----> 3 for order, file in enumerate(files):
#       5     with open( file, 'r', encoding='utf-8') as file:
#       6         soup = BeautifulSoup(file, 'html.parser')
#
# NameError: name 'files' is not defined

# %%
df['Content']
# Out:
# 0
# 1       Or at least just respect that you eat the way ...
# 2       Do you guys have a recommendation on how to in...
# 3       Yeah I was trying to help him he suffers from ...
# 4       Yeah, raw meat will help for sure, tell him to...
#                               ...
# 997                                        Fuckin psychos
# 998     Maybe I better just settle down with some nice...
# 999     Yo Harry not gonna lie man this video is inter...
# 1000                                 Not a bad settle man
# 1001                                           You do you
# Name: Content, Length: 1002, dtype: object

# %%
df.isnull().sum()
# Out:
# User       0
# Time       0
# Content    0
# dtype: int64

# %%
# Load HTML file
with open('../data/raw_data/messages2.html', 'r', encoding='utf-8') as file:
    soup = BeautifulSoup(file, 'html.parser')

# %%
# Out:
# 100
# 107.0
